# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 05:36:29--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   171MB/s    in 0.4s
#
# 2024-03-31 05:36:31 (171 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 8889   1609.00464v2  This paper describes a new kind of knowledge r...    cs
# 10545   1207.4748v1  The problem of hierarchical clustering items f...  stat
# 24039  1612.03142v2  While natural beauty is often considered a sub...    cs
# 9513   1605.01138v2  Humans demonstrate remarkable abilities to pre...    cs
# 10831   1408.3467v1  Deeply rooted in classical social choice and v...  stat
# ...             ...                                                ...   ...
# 21581   1103.6119v1  In this paper, auto-associative models are pro...  stat
# 7882   1604.06338v2  We present in this paper a simple, yet efficie...    cs
# 9110   1505.07909v4  Intelligence Quotient (IQ) Test is a set of st...    cs
# 14669   0908.4413v1  This paper presents the system called PATATRAS...    cs
# 2701   1707.01164v1  We propose a framework for feature selection t...  stat
#
#                                                    title  year  \
# 8889   The Semantic Knowledge Graph: A compact, auto-...  2016
# 10545  Hierarchical Clustering using Randomly Selecte...  2012
# 24039           Understanding and Mapping Natural Beauty  2016
# 9513   A Comparative Evaluation of Approximate Probab...  2016
# 10831  Robust Statistical Ranking: Theory and Algorithms  2014
# ...                                                  ...   ...
# 21581  Auto-associative models, nonlinear Principal c...  2011
# 7882   Robust Audio Event Recognition with 1-Max Pool...  2016
# 9110   Solving Verbal Comprehension Questions in IQ T...  2015
# 14669  Multiple Retrieval Models and Regression Model...  2009
# 2701   Kernel Feature Selection via Conditional Covar...  2017
#
#                                                 keywords
# 8889   [describes, knowledge, representation, knowled...
# 10545  [hierarchical, clustering, similarities, scien...
# 24039  [considered, subjective, objective, quantifyin...
# 9513   [demonstrate, remarkable, abilities, understan...
# 10831  [classical, statistical, comparison, experienc...
# ...                                                  ...
# 21581  [associative, candidates, generalization, prin...
# 7882   [efficient, convolutional, architecture, recog...
# 9110   [intelligence, standardized, questions, intell...
# 14669  [retrieval, characteristics, retrieval, defini...
# 2701   [framework, selection, independence, covariate...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 8889     [describes, knowledge, representation, knowled...
# 10545    [hierarchical, clustering, similarities, scien...
# 24039    [considered, subjective, objective, quantifyin...
# 9513     [demonstrate, remarkable, abilities, understan...
# 10831    [classical, statistical, comparison, experienc...
#                                ...
# 37940    [introduce, implementation, algorithms, comput...
# 6293     [presented, straightforward, application, proc...
# 5192     [structured, predictors, overlapping, variable...
# 6575     [detection, ensembles, variational, approximat...
# 1080     [applications, outperforming, important, theor...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8832 words.
# Out of those 4617 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="01e59271-5d43-40b3-b75c-b62821ae4f38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01e59271-5d43-40b3-b75c-b62821ae4f38")) {                    Plotly.newPlot(                        "01e59271-5d43-40b3-b75c-b62821ae4f38",                        [{"x":["extracted","materialize","statistics","representation","complementary","underlying","preexisting","applications","intersecting","corresponding","representative","cleansing","dynamically","contribution","generated","combination","describes","relationships","knowledge","materialized","analytics","traversal","detection","reasoning","represented","widespread","interesting","graphical","classification","recommendations","processing","introduction","automatically","relationship","leverages","arbitrary","documents","traversed","represent","instantly","available","clustering","reconstruct","developed","similarity","hierarchical","disciplines","obtaining","networking","techniques","similarities","expectation","measurements","recovered","observations","significant","reconstructing","significantly","scientific","applicable","objective","crowdsourced","prediction","explicitly","understanding","throughout","unlabeled","incorporating","predicting","thousands","demonstrate","approaches","subjective","quantifying","addressed","application","quantitative","qualitative","considered","containing","improvements","approximate","probabilistic","architectures","analogies","experiments","consistent","evaluation","perceptual","comparisons","judgments","situations","asymmetries","systematic","qualitatively","convolutional","simulations","quantitatively","simulation","intuitive","encountered","comparative","predictions","abilities","experiences","concretely","remarkable","previously","instantiated","algorithms","generalize","statistical","promising","established","experienced","crowdsourcing","technique","estimator","uncontrolled","supported","formulates","classical","comparison","decomposition","framework","faithfully","consistency","multimedia","sociology","simulated","approximations","iteration","projection","principle","linearized","environment","translated","guarantees","operations","afterwards","transactions","monotonic","execution","programming","expressions","precisely","semantics","simultaneously","connectives","additional","combining","extension","illustrating","primitive","transaction","particular","necessarily","perceptron","structured","stochasticity","important","excellent","feedforward","performance","difficult","favorably","potential","deterministic","estimators","comparing","regularizer","structure","stochastic","activations","fundamentally","potentially","generalization","benchmark","considerably","different","classifier","rejection","illustrate","misclassified","synthetic","misclassification","introduce","properties","essential","optimality","functions","concentrate","classifiers","misclassifications","accurately","parallelism","synthesized","distributed","convergence","sequential"],"y":[119,3,60,367,39,133,2,452,2,146,39,2,36,67,163,132,77,63,366,2,24,3,314,135,90,16,75,56,509,17,289,27,178,82,36,90,84,3,123,3,272,170,26,210,125,105,10,33,5,388,42,38,52,11,70,259,16,283,33,45,167,9,223,72,158,26,34,55,75,20,560,418,29,8,41,248,74,58,126,56,109,94,165,115,11,601,86,254,24,34,10,56,2,35,25,360,49,26,75,39,17,45,92,16,13,6,25,97,5,602,45,159,102,57,9,16,229,27,7,15,7,99,132,71,547,7,64,8,0,52,38,34,29,59,4,124,12,53,76,10,7,13,24,115,46,29,100,115,3,122,94,88,13,7,5,294,14,21,94,3,355,31,18,889,121,20,161,41,16,83,17,352,135,25,9,44,98,195,31,733,152,5,81,5,136,14,347,222,62,23,208,5,125,3,83,11,17,96,112,65],"type":"bar"},{"x":["extracted","materialize","statistics","represen ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4617,), (4617, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7966666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Biology</span> <span style=''>of</span> <span style=''>Applied</span> <span style=''>Digital</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Ecosystems</span> <br/><br/><span style=''>A</span> <span style=''>primary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivation</span> <span style=''>for</span> <span style=''>our</span> <span style=''>research</span> <span style=''>in</span> <span style=''>Digital</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Ecosystems</span> <span style=''>is</span> <span style=''>the</span> <span style=''>desire</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>the</span> <span style=''>self</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>organising</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biological</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>ecosystems</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Ecosystems</span> <span style=''>are</span> <span style=''>thought</span> <span style=''>to</span> <span style=''>be</span> <span style=''>robust</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>architectures</span> <span style=''>that</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.37984496124031003);'>automatically</span> <span style=''>solve</span> <span style=''>complex</span> <span style=''>dynamic</span> <span style=''>problems</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biological</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.5897435897435898);'>contribute</span> <span style=''>to</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>have</span> <span style=''>not</span> <span style=''>been</span> <span style=''>made</span> <span style=''>explicit</span> <span style=''>in</span> <span style=''>Digital</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Ecosystems</span> <span style=''>research</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>discuss</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biological</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style='background-color:rgba(0, 255, 0, 0.5897435897435898);'>contribute</span> <span style=''>to</span> <span style=''>the</span> <span style=''>self</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>organising</span> <span style=''>features</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biological</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>ecosystems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>dynamics</span> <span style='background-color:rgba(0, 255, 0, 0.4505494505494505);'>evolution</span> <span style=''>a</span> <span style=''>complex</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.6644295302013423);'>environment</span> <span style=''>and</span> <span style=''>spatial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generating</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploiting</span> <span style=''>these</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>on</span> <span style=''>Time</span> <span style=''>Series</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structural</span> <span style=''>Equation</span> <span style=''>Models</span> <br/><br/><span style=''>Causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>uses</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>to</span> <span style=''>infer</span> <span style=''>the</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style=''>system</span> <span style=''>We</span> <span style=''>study</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>models</span> <span style=''>that</span> <span style=''>we</span> <span style=''>call</span> <span style=''>Time</span> <span style=''>Series</span> <span style=''>Models</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Independent</span> <span style=''>Noise</span> <span style=''>(TiMINo)</span> <span style=''>These</span> <span style=''>models</span> <span style=''>require</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>residual</span> <span style=''>time</span> <span style=''>series</span> <span style=''>whereas</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>methods</span> <span style=''>like</span> <span style=''>Granger</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>causality</span> <span style=''>exploit</span> <span style=''>the</span> <span style=''>variance</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>residuals</span> <span style=''>There</span> <span style=''>are</span> <span style=''>two</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contributions</span> <span style=''>(1)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Theoretical</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricting</span> <span style=''>the</span> <span style=''>model</span> <span style=''>class</span> <span style=''>(eg</span> <span style=''>to</span> <span style=''>additive</span> <span style=''>noise)</span> <span style=''>we</span> <span style=''>can</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>more</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifiability</span> <span style=''>result</span> <span style=''>than</span> <span style=''>existing</span> <span style=''>ones</span> <span style=''>This</span> <span style=''>result</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporates</span> <span style=''>lagged</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instantaneous</span> <span style=''>effects</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>and</span> <span style=''>do</span> <span style=''>not</span> <span style=''>need</span> <span style=''>to</span> <span style=''>be</span> <span style=''>faithful</span> <span style=''>and</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instantaneous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>feedbacks</span> <span style=''>between</span> <span style=''>the</span> <span style=''>time</span> <span style=''>series</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Computation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3684210526315789);'>Variances</span> <span style=''>in</span> <span style=''>Causal</span> <span style=''>Networks</span> <br/><br/><span style=''>The</span> <span style=''>causal</span> <span style=''>(belief)</span> <span style=''>network</span> <span style=''>is</span> <span style=''>a</span> <span style=''>well</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.30864197530864196);'>graphical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.5130434782608695);'>representing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independencies</span> <span style=''>in</span> <span style=''>a</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>The</span> <span style=''>exact</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>methods</span> <span style=''>which</span> <span style=''>perform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3158756137479543);'>inference</span> <span style=''>in</span> <span style=''>causal</span> <span style=''>networks</span> <span style=''>often</span> <span style=''>treat</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>which</span> <span style=''>are</span> <span style=''>stored</span> <span style=''>in</span> <span style=''>the</span> <span style=''>network</span> <span style=''>as</span> <span style=''>certain</span> <span style=''>values</span> <span style=''>However</span> <span style=''>if</span> <span style=''>one</span> <span style=''>takes</span> <span style=''>either</span> <span style=''>a</span> <span style=''>subjectivistic</span> <span style=''>or</span> <span style=''>a</span> <span style=''>limiting</span> <span style='background-color:rgba(0, 255, 0, 0.4054054054054054);'>frequency</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>one</span> <span style=''>can</span> <span style=''>never</span> <span style=''>be</span> <span style=''>certain</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>values</span> <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3158756137479543);'>inference</span> <span style=''>should</span> <span style=''>not</span> <span style=''>only</span> <span style=''>be</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>reporting</span> <span style=''>the</span> <span style=''>inferred</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>it</span> <span style=''>should</span> <span style=''>also</span> <span style=''>be</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>reporting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>relative</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Enhancement</span> <span style=''>of</span> <span style=''>land</span> <span style=''>use</span> <span style=''>change</span> <span style=''>modeling</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighborhood</span> <span style=''>effect</span> <span style=''>is</span> <span style=''>a</span> <span style=''>key</span> <span style=''>driving</span> <span style=''>factor</span> <span style=''>for</span> <span style=''>the</span> <span style=''>land</span> <span style=''>use</span> <span style=''>change</span> <span style=''>(LUC)</span> <span style=''>process</span> <span style=''>This</span> <span style=''>study</span> <span style=''>applies</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(CNN)</span> <span style=''>to</span> <span style=''>capture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighborhood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristics</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satellite</span> <span style=''>images</span> <span style=''>and</span> <span style=''>to</span> <span style=''>enhance</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>LUC</span> <span style=''>modeling</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>hybrid</span> <span style=''>CNN</span> <span style=''>model</span> <span style=''>(conv</span> <span style=''>net)</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>the</span> <span style=''>LU</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combining</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satellite</span> <span style=''>images</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>geographical</span> <span style=''>features</span> <span style=''>A</span> <span style=''>spatial</span> <span style=''>weight</span> <span style=''>layer</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>the</span> <span style=''>distance</span> <span style=''>decay</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristics</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighborhood</span> <span style=''>effect</span> <span style=''>into</span> <span style=''>conv</span> <span style=''>net</span> <span style=''>As</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>model</span> <span style=''>we</span> <span style=''>also</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>hybrid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoder</span> <span style=''>and</span> <span style=''>multi</span> <span style=''>layer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perceptron</span> <span s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13088445078459343)
# 	processing (0.10306704707560628)
# 	architecture (0.0920114122681883)
# 	experimental (0.14122681883024252)
# 	knowledge (0.13052781740370897)
# 	detection (0.11198288159771755)
# 	different (0.26141226818830243)
# 	information (0.25463623395149787)
# 	convolutional (0.12838801711840228)
# 	recognition (0.12981455064194009)
#
# Some Statistics words are:
# 	stochastic (0.13326653306613226)
# 	estimation (0.16182364729458917)
# 	statistical (0.1523046092184369)
# 	theoretical (0.15280561122244488)
# 	distribution (0.17585170340681364)
# 	variables (0.14478957915831664)
# 	algorithm (0.407314629258517)
# 	dimensional (0.18286573146292584)
# 	inference (0.20140280561122245)
# 	regression (0.17685370741482967)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e582eb27-f2dd-45ad-88b5-6f9beb8d3eb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e582eb27-f2dd-45ad-88b5-6f9beb8d3eb7")) {                    Plotly.newPlot(                        "e582eb27-f2dd-45ad-88b5-6f9beb8d3eb7",                        [{"x":["extracted","materialize","statistics","representation","complementary","underlying","preexisting","applications","intersecting","corresponding","representative","cleansing","dynamically","contribution","generated","combination","describes","relationships","knowledge","materialized","analytics","traversal","detection","reasoning","represented","widespread","interesting","graphical","classification","recommendations","processing","introduction","automatically","relationship","leverages","arbitrary","documents","traversed","represent","instantly","available","clustering","reconstruct","developed","similarity","hierarchical","disciplines","obtaining","networking","techniques","similarities","expectation","measurements","recovered","observations","significant","reconstructing","significantly","scientific","applicable","objective","crowdsourced","prediction","explicitly","understanding","throughout","unlabeled","incorporating","predicting","thousands","demonstrate","approaches","subjective","quantifying","addressed","application","quantitative","qualitative","considered","containing","improvements","approximate","probabilistic","architectures","analogies","experiments","consistent","evaluation","perceptual","comparisons","judgments","situations","asymmetries","systematic","qualitatively","convolutional","simulations","quantitatively","simulation","intuitive","encountered","comparative","predictions","abilities","experiences","concretely","remarkable","previously","instantiated","algorithms","generalize","statistical","promising","established","experienced","crowdsourcing","technique","estimator","uncontrolled","supported","formulates","classical","comparison","decomposition","framework","faithfully","consistency","multimedia","sociology","simulated","approximations","iteration","projection","principle","linearized","environment","translated","guarantees","operations","afterwards","transactions","monotonic","execution","programming","expressions","precisely","semantics","simultaneously","connectives","additional","combining","extension","illustrating","primitive","transaction","particular","necessarily","perceptron","structured","stochasticity","important","excellent","feedforward","performance","difficult","favorably","potential","deterministic","estimators","comparing","regularizer","structure","stochastic","activations","fundamentally","potentially","generalization","benchmark","considerably","different","classifier","rejection","illustrate","misclassified","synthetic","misclassification","introduce","properties","essential","optimality","functions","concentrate","classifiers","misclassifications","accurately","parallelism","synthesized","distributed","convergence","sequential","facilitating","efficient","described","construction","empirical","partitions","objectives","supervised","decomposed","regularization","computationally","development","experimental","behaviors","engagement","fundamental","behavioral","forecasting","operational","simulating","successful","production","optimization","beforehand","variables","monetization","developers","experience","traditional","purchases","posterior","assumptions","generative","thresholds","parameter","community","identified","estimation","performing","inference","parametric","requiring","operators","formulated","resulting","computational","typically","transition","probability","dimensional","determine","generally","presented","ass ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	sociology
# 	hoeffding
# 	vegetation
# 	accompanying
# 	embarrassingly
# 	regulatory
# 	timescales
# 	contamination
# 	discriminable
# 	curvatures
# 	transplantation
# 	subpopulation
# 	scleroderma
# 	autoimmune
# 	frequentist
# 	microwave
# 	topography
# 	nonstandard
# 	connectome
# 	standardization
# Some words which never appear in Statistics papers:
# 	materialize
# 	materialized
# 	traversed
# 	instantly
# 	connectives
# 	reminiscent
# 	randomised
# 	contextuality
# 	contradictions
# 	predicates
# 	perimeter
# 	eligibility
# 	randomizing
# 	revolutionary
# 	simplifies
# 	repertoire
# 	sigmoidal
# 	conventions
# 	communicative
# 	saturation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.062130630492697e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
